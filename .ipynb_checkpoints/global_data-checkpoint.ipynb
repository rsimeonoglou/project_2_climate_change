# %%
import pandas as pd
import datetime as dt
from datetime import timedelta
from sqlalchemy import create_engine
import sqlite3

pd.set_option("display.max_rows", 50, "display.max_columns", None)

# %%
global_df = pd.read_csv("GlobalTemperatures.csv")
global_df
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187      8/1/15                  14.755                              0.072
# 3188      9/1/15                  12.999                              0.079
# 3189     10/1/15                  10.801                              0.102
# 3190     11/1/15                   7.433                              0.119
# 3191     12/1/15                   5.518                              0.100
#
# ...

# %%
global_df['dt'] = pd.to_datetime(global_df['dt'])
global_df['Year'] = global_df["dt"].dt.year
global_df['Month'] = global_df["dt"].dt.month
global_df['Day'] = global_df["dt"].dt.day

#datetime changed 1900-1970 to 2000s, need to correct
df_before_1900 = global_df.iloc[:1800]
df_after_1970 = global_df.iloc[2652:]

df_1900_to_1970 = global_df.iloc[1800:2652]         
df_1900_to_1970["Year"] = df_1900_to_1970["Year"]-100
df_1900_to_1970['dt'] = df_1900_to_1970["Year"].astype(str) + "-" + df_1900_to_1970["Month"].astype(str) + "-" + df_1900_to_1970["Day"].astype(str)
df_1900_to_1970['dt'] = pd.to_datetime(df_1900_to_1970['dt'])

global_df = pd.concat([df_before_1900,df_1900_to_1970,df_after_1970],ignore_index=True)
global_df
# Out:
# C:\Users\udayg\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\udayg\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\udayg\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# ...

# %%
global_df = global_df.loc[(global_df["Year"] > 1792)]
global_df = global_df.loc[(global_df["Year"] < 2014)]
global_df
# Out:
#              dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 516  1793-01-01                   0.521                              2.674
# 517  1793-02-01                   4.745                              2.624
# 518  1793-03-01                   5.042                              2.145
# 519  1793-04-01                   8.643                              1.904
# 520  1793-05-01                  11.059                              1.544
# ...         ...                     ...                                ...
# 3163 2013-08-01                  14.742                              0.129
# 3164 2013-09-01                  13.154                              0.104
# 3165 2013-10-01                  10.256                              0.077
# 3166 2013-11-01                   7.424                              0.079
# 3167 2013-12-01                   4.724                              0.085
#
# ...

# %%
#celcius to F calc (0°C × 9/5) + 32 

global_df["land_avg_fahrenheit"] = (global_df["LandAverageTemperature"] * 9/5) +32
global_df.reset_index(inplace=True) 
global_df
# Out:
#       index         dt  LandAverageTemperature  \
# 0       516 1793-01-01                   0.521
# 1       517 1793-02-01                   4.745
# 2       518 1793-03-01                   5.042
# 3       519 1793-04-01                   8.643
# 4       520 1793-05-01                  11.059
# ...     ...        ...                     ...
# 2647   3163 2013-08-01                  14.742
# 2648   3164 2013-09-01                  13.154
# 2649   3165 2013-10-01                  10.256
# 2650   3166 2013-11-01                   7.424
# 2651   3167 2013-12-01                   4.724
#
#       LandAverageTemperatureUncertainty  LandMaxTemperature  \
# 0                                 2.674                 NaN
# 1                                 2.624                 NaN
# 2                                 2.145                 NaN
# 3                                 1.904                 NaN
# 4                                 1.544                 NaN
# ...

# %%
# connection_string = "postgres:postgres@localhost:5432/project_2"
# engine = create_engine(f'postgresql://{connection_string}')

# global_df.to_sql(name='global_data', con=engine, if_exists='append', index=True)

# %%
# connection = engine.connect()
# global_yearly_land_avg = pd.read_sql("SELECT * FROM global_data", connection)
# global_yearly_land_avg

# %%
global_df_groupby = global_df.groupby("Year").mean()
global_df_groupby = global_df_groupby[["LandAverageTemperature","land_avg_fahrenheit"]].reset_index()
global_df_groupby
# Out:
#      Year  LandAverageTemperature  land_avg_fahrenheit
# 0    1793                8.229167             46.81250
# 1    1794                8.526000             47.34680
# 2    1795                8.350333             47.03060
# 3    1796                8.271000             46.88780
# 4    1797                8.510583             47.31905
# ..    ...                     ...                  ...
# 216  2009                9.505250             49.10945
# 217  2010                9.703083             49.46555
# 218  2011                9.516000             49.12880
# 219  2012                9.507333             49.11320
# 220  2013                9.606500             49.29170
#
# [221 rows x 3 columns]

# %%
global_df_groupby["Period"] = 0
counter = 0

for index, row in global_df_groupby.iterrows():
    counter = counter + 1
    if counter == 11:
        counter = 1
        global_df_groupby.loc[index, 'Period'] = counter
    else:
        global_df_groupby.loc[index, 'Period'] = counter

global_df_groupby
# Out:
#      Year  LandAverageTemperature  land_avg_fahrenheit  Period
# 0    1793                8.229167             46.81250       1
# 1    1794                8.526000             47.34680       2
# 2    1795                8.350333             47.03060       3
# 3    1796                8.271000             46.88780       4
# 4    1797                8.510583             47.31905       5
# ..    ...                     ...                  ...     ...
# 216  2009                9.505250             49.10945       7
# 217  2010                9.703083             49.46555       8
# 218  2011                9.516000             49.12880       9
# 219  2012                9.507333             49.11320      10
# 220  2013                9.606500             49.29170       1
#
# [221 rows x 4 columns]

# %%
plot_df = global_df_groupby[["Year", "land_avg_fahrenheit"]]

plot_df
## Filtering dataframe to retrieve data starting 1990 into database

# glo_df = global_df_groupby.loc[(global_df_groupby["Year"]>=1900)]

# %%
## Saving filtered data (>=1900) into Global-Warming db to connect flask

# engine = create_engine('postgresql://postgres:Aadhya2014@localhost:5432/Global-Warming')
# glo_df.to_sql('globaltemperatures', engine, if_exists='replace',index=False)

# %%
## Saving filtered data (>=1900) into a json file

# glo_df.to_json('data1.json', orient = 'split', compression = 'infer', index = 'true')

# %%
global_df_decades = global_df_groupby.loc[(global_df_groupby["Period"]==1) |
                                         (global_df_groupby["Period"]==10)]
global_df_decades

global_df_decades["temp_change"] = 0
global_df_decades["year_range"] = 0
temp_change = 0
beg_temp = 0

for index, row in global_df_decades.iterrows():
    
    if row["Period"] == 1:
        beg_temp = row["land_avg_fahrenheit"]
        beg_year = int(row["Year"])
        global_df_decades.loc[index, 'temp_change'] = 0
    else:
        temp_change = row["land_avg_fahrenheit"] - beg_temp
        global_df_decades.loc[index, 'temp_change'] = temp_change
        end_year = int(row["Year"]+1)
        year_range = "{} - {}".format(beg_year,end_year)
        global_df_decades.loc[index, 'year_range'] = year_range

global_df_decades
# Out:
# <ipython-input-106-7a6e2d0cc5dd>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_df_decades["temp_change"] = 0
# <ipython-input-106-7a6e2d0cc5dd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_df_decades["year_range"] = 0
# /Users/robertsimeonoglou/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
global_df_decades = global_df_decades.loc[global_df_decades['Period']==10]
global_df_decades
